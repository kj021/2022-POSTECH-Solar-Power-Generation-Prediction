# %% [markdown]
# # 1. 예측 발전량 api를 통해 입찰하기

# %%
_API_URL = 'https://research-api.dershare.xyz'
# _API_KEY 직접 입력
_API_KEY = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJoSDROSE5yNXFiTjV4RmpBRzdHNFo4IiwiaWF0IjoxNjY4NDA0NTY5LCJleHAiOjE2Njg3ODM2MDAsInR5cGUiOiJhcGlfa2V5In0.0nLO_EIlJKASfurF8mp6UZBFEc40Q-LX3UHGbUtCNEM'
_AUTH_PARAM = {'headers': {'Authorization': f'Bearer {_API_KEY}'}}

# %% [markdown]
# -0.294556132	-0.286635028
# -0.347983671	-0.192426765
# -0.087226812	-0.183971085
# 0.08626683	-0.236849183
# 0.291659795	-0.362534211
# 0.515351921	-0.253309397
# 0.066122202	-0.348903178
# 1.297241225	-0.333948004
# 1.148179383	33.98107966
# 26.89657211	37.58283346
# 32.37685539	44.4268538
# 29.6237735	42.32286525
# 30.8168433	43.4543151
# 26.60478226	44.50082261
# 21.64414161	29.94970448
# 1.08104729	-0.058950311
# 0.558029856	0.176959155
# 0.754107773	-0.07371085
# 0.252075218	-0.3391714
# 1.759149452	-0.396684137
# 1.272221159	-0.492819287
# 0.576525984	-0.590722449
# 0.920185142	-0.328488284
# 0.02620817	0.198576532

# %%
"""#2022 11월14일 발전량 예측(14,13일 기상예측데이터를 사용하여 구간생성)
def get_bids(bid_round= int):
    '''It returns bids of a round.'''
    # yapf: disable
    if bid_round == 1:
        return [{'upper': 0 , 'lower': 0  },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 1.297241225, 'lower': 0 },
                {'upper': 1.148179383, 'lower': 33.98107966 },
                {'upper': 26.89657211, 'lower':37.58283346  },
                {'upper': 32.37685539, 'lower': 44.4268538 	 },
                {'upper': 29.6237735, 'lower': 42.32286525 },
                {'upper': 30.8168433, 'lower': 43.4543151	 },
                {'upper': 26.60478226, 'lower': 44.50082261	 },
                {'upper': 21.64414161, 'lower': 29.94970448 },
                {'upper': 1.08104729, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower': 0},]
    if bid_round == 2: 
        return [{'upper': 0 , 'lower': 0  },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 1.297241225, 'lower': 0 },
                {'upper': 1.148179383, 'lower': 33.98107966 },
                {'upper': 26.89657211, 'lower':37.58283346  },
                {'upper': 32.37685539, 'lower': 44.4268538 	 },
                {'upper': 29.6237735, 'lower': 42.32286525 },
                {'upper': 30.8168433, 'lower': 43.4543151	 },
                {'upper': 26.60478226, 'lower': 44.50082261	 },
                {'upper': 21.64414161, 'lower': 29.94970448 },
                {'upper': 1.08104729, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower': 0}]    
    
    return [{'upper': 0, 'lower': 0}]*24 """

# %%
"""#2022 11월14일 발전량 예측(14일 기상예측데이터를 사용하여 구간생성)
def get_bids(bid_round= int):
    '''It returns bids of a round.'''
    # yapf: disable
    if bid_round == 1:
        return [{'upper': 0 , 'lower': 0  },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 1.297241225, 'lower': 1.297241225 },
                {'upper': 1.148179383, 'lower': 1.148179383 },
                {'upper': 26.89657211, 'lower':26.89657211  },
                {'upper': 32.37685539, 'lower': 32.37685539 	 },
                {'upper': 29.6237735, 'lower': 29.6237735 },
                {'upper': 30.8168433, 'lower': 30.8168433	 },
                {'upper': 26.60478226, 'lower': 26.60478226	 },
                {'upper': 21.64414161, 'lower': 21.64414161 },
                {'upper': 1.08104729, 'lower': 1.08104729},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower': 0},]
    if bid_round == 2: 
        return [{'upper': 0 , 'lower': 0  },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 1.297241225, 'lower': 1.297241225 },
                {'upper': 1.148179383, 'lower': 1.148179383 },
                {'upper': 26.89657211, 'lower':26.89657211  },
                {'upper': 32.37685539, 'lower': 32.37685539 	 },
                {'upper': 29.6237735, 'lower': 29.6237735 },
                {'upper': 30.8168433, 'lower': 30.8168433	 },
                {'upper': 26.60478226, 'lower': 26.60478226	 },
                {'upper': 21.64414161, 'lower': 21.64414161 },
                {'upper': 1.08104729, 'lower': 1.08104729},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower': 0}]
    return [{'upper': 0, 'lower': 0}]*24 """

# %%
#2022 11월14일 발전량 예측(13일 기상예측데이터를 사용하여 구간생성)
def get_bids(bid_round= int):
    '''It returns bids of a round.'''
    # yapf: disable
    if bid_round == 1:
        return [{'upper': 0 , 'lower': 0  },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 33.98107966, 'lower': 33.98107966 },
                {'upper': 37.58283346, 'lower':37.58283346  },
                {'upper': 44.4268538, 'lower': 44.4268538 	 },
                {'upper': 42.32286525, 'lower': 42.32286525 },
                {'upper': 43.4543151, 'lower': 43.4543151	 },
                {'upper': 44.50082261, 'lower': 44.50082261	 },
                {'upper': 29.94970448, 'lower': 29.94970448 },
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower': 0},]
    if bid_round == 2: 
        return [{'upper': 0 , 'lower': 0  },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0 },
                {'upper': 33.98107966, 'lower': 33.98107966 },
                {'upper': 37.58283346, 'lower':37.58283346  },
                {'upper': 44.4268538, 'lower': 44.4268538 	 },
                {'upper': 42.32286525, 'lower': 42.32286525 },
                {'upper': 43.4543151, 'lower': 43.4543151	 },
                {'upper': 44.50082261, 'lower': 44.50082261	 },
                {'upper': 29.94970448, 'lower': 29.94970448 },
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower': 0 },
                {'upper': 0, 'lower': 0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower':  0},
                {'upper': 0, 'lower': 0}]
    return [{'upper': 0, 'lower': 0}]*24

# %%
"""#예측 발전량 입찰
import requests
import json

amounts = amounts= get_bids(bid_round= 2)
success = requests.post(f'https://research-api.dershare.xyz/open-proc/cmpt-2022/bids', data=json.dumps(amounts), headers={
                            'Authorization': f'Bearer {_API_KEY}'
                        }).json()
print(success)"""
# Out:
# True

# %% [markdown]
# # 2.예측 오차 확인하기

# %%
#예측일 실제 발전량데이터(11,12일데이터를 불러와야지 24시간 11일데이터를 전부 얻을 수 있음)
import requests
import pandas as pd
import json

date = '2022-11-12'
pv_gens = requests.get(f'https://research-api.dershare.xyz/open-proc/cmpt-2022/pv-gens/{date}', headers={
                            'Authorization': f'Bearer {_API_KEY}'
                        }).json()
                        
pv_gens1 = json.dumps(pv_gens)
pv_gens11 = json.loads(pv_gens1)
df_pvgens= pd.DataFrame(pv_gens11)
pd.set_option('display.max_rows', None)#모든행 출력
df_pvgens
#df_pvgens.to_csv("pv_gens1112.csv")
# Out:
#      pv_id                       time   amount
# 0        0  2022-11-11T16:00:00+00:00    0.000
# 1        1  2022-11-11T16:00:00+00:00    0.000
# 2        2  2022-11-11T16:00:00+00:00    0.000
# 3        3  2022-11-11T16:00:00+00:00    0.000
# 4        4  2022-11-11T16:00:00+00:00    0.000
# 5        5  2022-11-11T16:00:00+00:00    0.000
# 6        6  2022-11-11T16:00:00+00:00    0.009
# 7        7  2022-11-11T16:00:00+00:00    0.012
# 8        8  2022-11-11T16:00:00+00:00    0.000
# 9        9  2022-11-11T16:00:00+00:00    0.000
# 10      10  2022-11-11T16:00:00+00:00    0.000
# 11      11  2022-11-11T16:00:00+00:00    0.000
# 12      12  2022-11-11T16:00:00+00:00    0.000
# 13      13  2022-11-11T16:00:00+00:00    0.000
# 14      14  2022-11-11T16:00:00+00:00    0.000
# 15      15  2022-11-11T16:00:00+00:00    0.000
# 16      16  2022-11-11T16:00:00+00:00    0.000
# 17      17  2022-11-11T16:00:00+00:00    0.000
# 18      18  2022-11-11T16:00:00+00:00    0.012
# ...

# %%
'''OIBC 입찰평가 샘플코드.
- 거래일 전날 10시와 17시, 2회에 걸쳐 거래일의 발전량 예측치를 제출
- 값이 작을수록 우수한 것으로 평가
- 예측 구간의 평균값을 기준으로 한 예측 오차, 예측 구간의 범위, 실제 발전량이 예측 구간에 포함 여부를 평가 산식에 반영
'''
from typing import List

TOTAL_CAPACITY = 472.39
ONE_HOUR_SEC = 3600
BID_ROUNDS = (1, 2)

def get_gens() -> List[float]:
    '''It returns pv power generations of a group.'''
    # yapf: disable
    return [0,0,0 ,0 ,0 ,0 ,0 ,8.200 ,25.100 ,50.100 ,124.700 ,184.400 ,294.900 ,293.300 ,222.800 ,151.300,48.200 ,5.100 , 0, 0, 0, 0, 0, 0]
    # yapf: enable


if __name__ == '__main__':
    gens = get_gens()
    sum_value: float = 0
    for idx, gen in enumerate(gens):
        util_errs = []
        for bid_round in BID_ROUNDS:
            bids = get_bids(bid_round)
            bid = bids[idx]
            real_gen = gens[idx]

            value = (
                (
                    0.45
                    * abs((bid['upper'] + bid['lower']) / 2 - real_gen)
                    / TOTAL_CAPACITY
                )
                + (0.45 * (bid['upper'] - bid['lower']) / (TOTAL_CAPACITY))
                + (
                    (
                        0.1
                        * (
                            real_gen
                            * (
                                1
                                if bid['lower'] > real_gen
                                or bid['upper'] < real_gen
                                else 0
                            )
                        )
                    )
                    / TOTAL_CAPACITY
                )
            )

            print(
                f'Idx({idx}), Round({bid_round}) | '
                f'Evaluation value: {value} (%) / '
                f'Bid: {bid} (kWh) / '
                f'Gen: {gen} (kWh)'
            )
            sum_value += value

    print(f'Total Evaluation value: {sum_value} (KRW)')
# Out:
# Idx(0), Round(1) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# Idx(0), Round(2) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# Idx(1), Round(1) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# Idx(1), Round(2) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# Idx(2), Round(1) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# Idx(2), Round(2) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# Idx(3), Round(1) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# Idx(3), Round(2) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# Idx(4), Round(1) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# Idx(4), Round(2) | Evaluation value: 0.0 (%) / Bid: {'upper': 0, 'lower': 0} (kWh) / Gen: 0 (kWh)
# ...

# %% [markdown]
# Total Evaluation value: 2.6528616309502753 (KRW)
